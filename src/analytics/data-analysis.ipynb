# %%
import pandas as pd
import numpy as np
from analiticsLabels import *
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-da209d295e89> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from analiticsLabels import *
#
# ~/pyx4-avoidance/src/analytics/analiticsLabels.py in <module>
# ----> 1 from analiticsVars import *
#       2
#       3
#       4 class AnalyticsLabels(object):
#       5     """Generate labels for topics and vice-versa
#
# ~/pyx4-avoidance/src/analytics/analiticsVars.py in <module>
#      35 }
#      36
# ---> 37 TOPICS = [k for k, v in TOPICS_TO_LABELS.iteritems()]
#      38
#      39 LABELS_TO_TOPICS = {v: k for k, v in
#
# AttributeError: 'dict' object has no attribute 'iteritems'

# %%
df = pd.read_csv('data/3-tree-xvel-20-fov-30.csv')

# %%
df.sort_values('distance')
df = df[]
# Out:
#              time                                         optic_flow  \
# 124  5.801000e+11  [[[  2.74397991e-07   3.78077516e-07]\n  [  2....
# 123  5.800000e+11  [[[ -1.37242409e-06   6.90529703e-07]\n  [ -1....
# 122  5.799000e+11  [[[ -1.35100167e-10  -9.43194411e-10]\n  [  3....
# 121  5.798000e+11  [[[  6.59933844e-11   8.90667595e-10]\n  [ -3....
# 120  5.797000e+11  [[[  7.75989122e-07   1.25679776e-07]\n  [  6....
# ..            ...                                                ...
# 4    5.678000e+11  [[[  2.62434384e-07   2.61357172e-06]\n  [  7....
# 3    5.677000e+11  [[[ -3.06507809e-06   4.04154980e-06]\n  [ -3....
# 2    5.676000e+11  [[[  4.97390420e-06   3.80829306e-06]\n  [  5....
# 1    5.675000e+11  [[[  4.74345006e-06  -4.13260886e-06]\n  [  5....
# 0    5.674000e+11  [[[  1.99321084e-06  -6.59277077e-08]\n  [  1....
#
#      activation  optic_flow_cn45  activation_cn45  optic_flow_c45   distance  \
# ...
